# %%
! pip install scispacy
! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.0/en_core_sci_lg-0.5.0.tar.gz
! pip install pandas
! pip install requests
! pip install requests pandas
! pip install json
! pip install argparse
! pip install shelve
! pip install scispacy
! pip install scispacy.linking
! pip install datetime
# !pip install tabulate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scispacy in ./.local/lib/python3.9/site-packages (0.5.5)
# Requirement already satisfied: scikit-learn>=0.20.3 in ./.local/lib/python3.9/site-packages (from scispacy) (1.5.2)
# Requirement already satisfied: conllu in ./.local/lib/python3.9/site-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (from scispacy) (1.26.4)
# Requirement already satisfied: joblib in ./.local/lib/python3.9/site-packages (from scispacy) (1.4.2)
# Requirement already satisfied: nmslib>=1.7.3.6 in ./.local/lib/python3.9/site-packages (from scispacy) (2.1.1)
# Requirement already satisfied: scipy in ./.local/lib/python3.9/site-packages (from scispacy) (1.13.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from scispacy) (2.26.0)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in ./.local/lib/python3.9/site-packages (from scispacy) (3.7.5)
# Requirement already satisfied: pysbd in ./.local/lib/python3.9/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: psutil in /opt/tljh/user/lib/python3.9/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.1)
# Requirement already satisfied: pybind11<2.6.2 in ./.local/lib/python3.9/site-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.local/lib/python3.9/site-packages (from scikit-learn>=0.20.3->scispacy) (3.5.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (21.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Requirement already satisfied: jinja2 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.10.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: setuptools in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (58.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.11)
# Requirement already satisfied: language-data>=1.2 in ./.local/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/tljh/user/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.12.2)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (2.27.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in ./.local/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in ./.local/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in ./.local/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./.local/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/tljh/user/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./.local/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.local/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (3.0.0)
# Requirement already satisfied: wrapt in ./.local/lib/python3.9/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.0/en_core_sci_lg-0.5.0.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.0/en_core_sci_lg-0.5.0.tar.gz (532.3 MB)
#      |████████████████████████████████| 532.3 MB 42 kB/s
#   Preparing metadata (setup.py) ... done
# Collecting spacy<3.3.0,>=3.2.3
#   Downloading spacy-3.2.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 10.7 MB/s
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.0.5)
# Requirement already satisfied: setuptools in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (58.2.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.0.10)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (668 kB)
#      |████████████████████████████████| 668 kB 63.1 MB/s
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.5.0)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 12.6 MB/s
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15.0 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.26.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.0.9)
# Requirement already satisfied: jinja2 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.0.12)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 106.1 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.26.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.0.11)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 10.1 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (4.62.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.0.12)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (0.7.11)
# Collecting typing-extensions<4.6.0,>=3.7.4.1
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in ./.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.5.1)
# Requirement already satisfied: language-data>=1.2 in ./.local/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/tljh/user/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.0.9)
# Collecting pathlib-abc==0.1.1
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2022.6.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.local/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (8.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/tljh/user/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./.local/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.3.0,>=3.2.3->en-core-sci-lg==0.5.0) (1.2.1)
# Building wheels for collected packages: en-core-sci-lg
#   Building wheel for en-core-sci-lg (setup.py) ... done
#   Created wheel for en-core-sci-lg: filename=en_core_sci_lg-0.5.0-py3-none-any.whl size=532569822 sha256=f3b047fcec5b972ee48fc8343ef648a21e60a5e6723b96e5e62e3c4cf73d347d
#   Stored in directory: /home/jupyter-parumenon/.cache/pip/wheels/d7/3e/3a/71af6fdd9a698032300759047ad34ca1d138bd481ae51097e5
# Successfully built en-core-sci-lg
# Installing collected packages: typing-extensions, wasabi, typer, smart-open, pydantic, pathlib-abc, thinc, pathy, spacy, en-core-sci-lg
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.12.2
#     Uninstalling typing-extensions-4.12.2:
#       Successfully uninstalled typing-extensions-4.12.2
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.1
#     Uninstalling typer-0.15.1:
#       Successfully uninstalled typer-0.15.1
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.1.0
#     Uninstalling smart-open-7.1.0:
#       Successfully uninstalled smart-open-7.1.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.5
#     Uninstalling thinc-8.2.5:
#       Successfully uninstalled thinc-8.2.5
#   WARNING: The script pathy is installed in '/home/jupyter-parumenon/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.5
#     Uninstalling spacy-3.7.5:
#       Successfully uninstalled spacy-3.7.5
#   WARNING: The script spacy is installed in '/home/jupyter-parumenon/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.5.1 requires typing-extensions>=4.8.0, but you have typing-extensions 4.5.0 which is incompatible.
# scispacy 0.5.5 requires spacy<3.8.0,>=3.7.0, but you have spacy 3.2.6 which is incompatible.
# pydantic-core 2.27.2 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed en-core-sci-lg-0.5.0 pathlib-abc-0.1.1 pathy-0.11.0 pydantic-1.8.2 smart-open-6.4.0 spacy-3.2.6 thinc-8.0.17 typer-0.4.2 typing-extensions-4.5.0 wasabi-0.10.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in ./.local/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /opt/tljh/user/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (3.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /opt/tljh/user/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: pandas in ./.local/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.22.4 in ./.local/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Defaulting to user installation because normal site-packages is not writeable
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement shelve (from versions: none)
# ERROR: No matching distribution found for shelve
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scispacy in ./.local/lib/python3.9/site-packages (0.5.5)
# Requirement already satisfied: scipy in ./.local/lib/python3.9/site-packages (from scispacy) (1.13.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from scispacy) (2.26.0)
# Requirement already satisfied: joblib in ./.local/lib/python3.9/site-packages (from scispacy) (1.4.2)
# Requirement already satisfied: conllu in ./.local/lib/python3.9/site-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (from scispacy) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in ./.local/lib/python3.9/site-packages (from scispacy) (1.5.2)
# Collecting spacy<3.8.0,>=3.7.0
#   Using cached spacy-3.7.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
# Requirement already satisfied: nmslib>=1.7.3.6 in ./.local/lib/python3.9/site-packages (from scispacy) (2.1.1)
# Requirement already satisfied: pysbd in ./.local/lib/python3.9/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: psutil in /opt/tljh/user/lib/python3.9/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.1)
# Requirement already satisfied: pybind11<2.6.2 in ./.local/lib/python3.9/site-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.6.15)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.local/lib/python3.9/site-packages (from scikit-learn>=0.20.3->scispacy) (3.5.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.2)
# Requirement already satisfied: jinja2 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.5.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.8.2)
# Requirement already satisfied: setuptools in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (58.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.5.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.11)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./.local/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Collecting thinc<8.3.0,>=8.2.2
#   Using cached thinc-8.2.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (937 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/tljh/user/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.62.3)
# Requirement already satisfied: language-data>=1.2 in ./.local/lib/python3.9/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/tljh/user/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.5.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.local/lib/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.8)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (6.4.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./.local/lib/python3.9/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/tljh/user/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./.local/lib/python3.9/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.1)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.17
#     Uninstalling thinc-8.0.17:
#       Successfully uninstalled thinc-8.0.17
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.6
#     Uninstalling spacy-3.2.6:
#       Successfully uninstalled spacy-3.2.6
#   WARNING: The script spacy is installed in '/home/jupyter-parumenon/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-sci-lg 0.5.0 requires spacy<3.3.0,>=3.2.3, but you have spacy 3.7.5 which is incompatible.
# Successfully installed spacy-3.7.5 thinc-8.2.5
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement scispacy.linking (from versions: none)
# ERROR: No matching distribution found for scispacy.linking
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 2.5 MB/s
# Collecting zope.interface
#   Downloading zope.interface-7.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253 kB)
#      |████████████████████████████████| 253 kB 22.3 MB/s
# Requirement already satisfied: pytz in /opt/tljh/user/lib/python3.9/site-packages (from datetime) (2022.1)
# Requirement already satisfied: setuptools in /opt/tljh/user/lib/python3.9/site-packages (from zope.interface->datetime) (58.2.0)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.5 zope.interface-7.2

# %%
import spacy
nlp = spacy.load("en_core_sci_lg")  
print("Model loaded successfully!")
# Out:
# /home/jupyter-parumenon/.local/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_sci_lg' (0.5.0) was trained with spaCy v3.2.3 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Model loaded successfully!

# %% [markdown]
# ## Apply spacy model, extract entities, get cuis and then crosswalk to icd10 codes for Eg text

# %%
#import all libraries
import spacy
import scispacy
from scispacy.linking import EntityLinker
import pandas as pd
from tabulate import tabulate
from IPython.display import display  # Import display function for Jupyter

# Load CSV containing UMLS_CUI and icd10 code mappings. These are extracted from umls mrconso file that is updated twice a year
csv_file_path = "umls_cuis.csv" 
code_df = pd.read_csv(csv_file_path, encoding="latin1")
print("File loaded successfully!")

# Load the large model with vector embeddings 
nlp = spacy.load("en_core_sci_lg")

# Adding the UMLS entity linker
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

print("Model loaded successfully!")

# input for our test case
text = "Patient presents with chest pain and nausea. He has a history of hypertension and type 2 diabetes."

# Applying the NLP model
doc = nlp(text)

# Initialize a list to hold all entities and their UMLS mappings
entities = []

# Extract entities and their UMLS links
for ent in doc.ents:
    print(f"Entity: {ent}, Label: {ent.label_}")

    # For each entity, look at the linked UMLS concepts
    for umls_ent in ent._.kb_ents:
        linker = nlp.get_pipe("scispacy_linker")
        concept = linker.kb.cui_to_entity[umls_ent[0]]
        
        # Extract the score for the UMLS entity match
        score = umls_ent[1]  # This contains the matching score
        
        # Append the entity details along with the score
        entities.append({
            "Text": ent.text,
            "Start": ent.start_char,
            "End": ent.end_char,
            "Label": ent.label_,
            "UMLS_CUI": concept.concept_id,
            "UMLS_Name": concept.canonical_name,
            "Score": score  # Add the score to the output
        })

# Convert the entities list to a DataFrame for easier viewing
entities_df = pd.DataFrame(entities)
print("Entities Created")

# Improve display settings for Jupyter
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", 50)  # Adjust number of rows displayed
pd.set_option("display.width", 1000)  # Prevent line wrapping

# Display the entities_df as a formatted table
display(entities_df.style.set_properties(**{"text-align": "left"}).set_table_styles(
    [{"selector": "th", "props": [("text-align", "left")]}]
))

# Rename "cui" to "UMLS_CUI" for consistency in umls-icd10 CSV file to match
#code_df.rename(columns={"cui": "UMLS_CUI"}, inplace=True)  

# Merge entities_df with the CSV file on "UMLS_CUI"
merged_df = entities_df.merge(code_df, on="UMLS_CUI", how="left")  

# Select the row with the highest Score for each entity- to reduce 1:many matches- this is optional
best_matches_df = merged_df.loc[merged_df.groupby("Text")["Score"].idxmax()]


# Display the final DataFrame as a formatted table
display(best_matches_df.style.set_properties(**{"text-align": "left"}).set_table_styles(
    [{"selector": "th", "props": [("text-align", "left")]}]
))
# Out:
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib
# /home/jupyter-parumenon/.local/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_sci_lg' (0.5.0) was trained with spaCy v3.2.3 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# File loaded successfully!
# /home/jupyter-parumenon/.local/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-parumenon/.local/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Model loaded successfully!
# Entity: Patient, Label: ENTITY
# Entity: chest pain, Label: ENTITY
# Entity: nausea, Label: ENTITY
# Entity: history, Label: ENTITY
# Entity: hypertension, Label: ENTITY
# Entity: type 2 diabetes, Label: ENTITY
# Entities Created
# <style type="text/css">
# #T_3a22e th {
#   text-align: left;
# }
# #T_3a22e_row0_col0, #T_3a22e_row0_col1, #T_3a22e_row0_col2, #T_3a22e_row0_col3, #T_3a22e_row0_col4, #T_3a22e_row0_col5, #T_3a22e_row0_col6, #T_3a22e_row1_col0, #T_3a22e_row1_col1, #T_3a22e_row1_col2, #T_3a22e_row1_col3, #T_3a22e_row1_col4, #T_3a22e_row1_col5, #T_3a22e_row1_col6, #T_3a22e_row2_col0, #T_3a22e_row2_col1, #T_3a22e_row2_col2, #T_3a22e_row2_col3, #T_3a22e_row2_col4, #T_3a22e_row2_col5, #T_3a22e_row2_col6, #T_3a22e_row3_col0, #T_3a22e_row3_col1, #T_3a22e_row3_col2, #T_3a22e_row3_col3, #T_3a22e_row3_col4, #T_3a22e_row3_col5, #T_3a22e_row3_col6, #T_3a22e_row4_col0, #T_3a22e_row4_col1, #T_3a22e_row4_col2, #T_3a22e_row4_col3, #T_3a22e_row4_col4, #T_3a22e_row4_col5, #T_3a22e_row4_col6, #T_3a22e_row5_col0, #T_3a22e_row5_col1, #T_3a22e_row5_col2, #T_3a22e_row5_col3, #T_3a22e_row5_col4, #T_3a22e_row5_col5, #T_3a22e_row5_col6, #T_3a22e_row6_col0, #T_3a22e_row6_col1, #T_3a22e_row6_col2, #T_3a22e_row6_col3, #T_3a22e_row6_col4, #T_3a22e_row6_col5, #T_3a22e_row6_col6, #T_3a22e_row7_col0, #T_3a22e_row7_col1, #T_3a22e_row7_col2, #T_3a22e_row7_col3, #T_3a22e_row7_col4, #T_3a22e_row7_col5, #T_3a22e_row7_col6, #T_3a22e_row8_col0, #T_3a22e_row8_col1, #T_3a22e_row8_col2, #T_3a22e_row8_col3, #T_3a22e_row8_col4, #T_3a22e_row8_col5, #T_3a22e_row8_col6, #T_3a22e_row9_col0, #T_3a22e_row9_col1, #T_3a22e_row9_col2, #T_3a22e_row9_col3, #T_3a22e_row9_col4, #T_3a22e_row9_col5, #T_3a22e_row9_col6, #T_3a22e_row10_col0, #T_3a22e_row10_col1, #T_3a22e_row10_col2, #T_3a22e_row10_col3, #T_3a22e_row10_col4, #T_3a22e_row10_col5, #T_3a22e_row10_col6, #T_3a22e_row11_col0, #T_3a22e_row11_col1, #T_3a22e_row11_col2, #T_3a22e_row11_col3, #T_3a22e_row11_col4, #T_3a22e_row11_col5, #T_3a22e_row11_col6, #T_3a22e_row12_col0, #T_3a22e_row12_col1, #T_3a22e_row12_col2, #T_3a22e_row12_col3, #T_3a22e_row12_col4, #T_3a22e_row12_col5, #T_3a22e_row12_col6, #T_3a22e_row13_col0, #T_3a22e_row13_col1, #T_3a22e_row13_col2, #T_3a22e_row13_col3, #T_3a22e_row13_col4, #T_3a22e_row13_col5, #T_3a22e_row13_col6, #T_3a22e_row14_col0, #T_3a22e_row14_col1, #T_3a22e_row14_col2, #T_3a22e_row14_col3, #T_3a22e_row14_col4, #T_3a22e_row14_col5, #T_3a22e_row14_col6, #T_3a22e_row15_col0, #T_3a22e_row15_col1, #T_3a22e_row15_col2, #T_3a22e_row15_col3, #T_3a22e_row15_col4, #T_3a22e_row15_col5, #T_3a22e_row15_col6, #T_3a22e_row16_col0, #T_3a22e_row16_col1, #T_3a22e_row16_col2, #T_3a22e_row16_col3, #T_3a22e_row16_col4, #T_3a22e_row16_col5, #T_3a22e_row16_col6, #T_3a22e_row17_col0, #T_3a22e_row17_col1, #T_3a22e_row17_col2, #T_3a22e_row17_col3, #T_3a22e_row17_col4, #T_3a22e_row17_col5, #T_3a22e_row17_col6, #T_3a22e_row18_col0, #T_3a22e_row18_col1, #T_3a22e_row18_col2, #T_3a22e_row18_col3, #T_3a22e_row18_col4, #T_3a22e_row18_col5, #T_3a22e_row18_col6, #T_3a22e_row19_col0, #T_3a22e_row19_col1, #T_3a22e_row19_col2, #T_3a22e_row19_col3, #T_3a22e_row19_col4, #T_3a22e_row19_col5, #T_3a22e_row19_col6, #T_3a22e_row20_col0, #T_3a22e_row20_col1, #T_3a22e_row20_col2, #T_3a22e_row20_col3, #T_3a22e_row20_col4, #T_3a22e_row20_col5, #T_3a22e_row20_col6, #T_3a22e_row21_col0, #T_3a22e_row21_col1, #T_3a22e_row21_col2, #T_3a22e_row21_col3, #T_3a22e_row21_col4, #T_3a22e_row21_col5, #T_3a22e_row21_col6, #T_3a22e_row22_col0, #T_3a22e_row22_col1, #T_3a22e_row22_col2, #T_3a22e_row22_col3, #T_3a22e_row22_col4, #T_3a22e_row22_col5, #T_3a22e_row22_col6, #T_3a22e_row23_col0, #T_3a22e_row23_col1, #T_3a22e_row23_col2, #T_3a22e_row23_col3, #T_3a22e_row23_col4, #T_3a22e_row23_col5, #T_3a22e_row23_col6, #T_3a22e_row24_col0, #T_3a22e_row24_col1, #T_3a22e_row24_col2, #T_3a22e_row24_col3, #T_3a22e_row24_col4, #T_3a22e_row24_col5, #T_3a22e_row24_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_3a22e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a22e_level0_col0" class="col_heading level0 col0" >Text</th>
#       <th id="T_3a22e_level0_col1" class="col_heading level0 col1" >Start</th>
#       <th id="T_3a22e_level0_col2" class="col_heading level0 col2" >End</th>
#       <th id="T_3a22e_level0_col3" class="col_heading level0 col3" >Label</th>
#       <th id="T_3a22e_level0_col4" class="col_heading level0 col4" >UMLS_CUI</th>
#       <th id="T_3a22e_level0_col5" class="col_heading level0 col5" >UMLS_Name</th>
#       <th id="T_3a22e_level0_col6" class="col_heading level0 col6" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a22e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a22e_row0_col0" class="data row0 col0" >Patient</td>
#       <td id="T_3a22e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3a22e_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_3a22e_row0_col3" class="data row0 col3" >ENTITY</td>
#       <td id="T_3a22e_row0_col4" class="data row0 col4" >C0030705</td>
#       <td id="T_3a22e_row0_col5" class="data row0 col5" >Patients</td>
#       <td id="T_3a22e_row0_col6" class="data row0 col6" >0.982997</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a22e_row1_col0" class="data row1 col0" >Patient</td>
#       <td id="T_3a22e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_3a22e_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_3a22e_row1_col3" class="data row1 col3" >ENTITY</td>
#       <td id="T_3a22e_row1_col4" class="data row1 col4" >C1550655</td>
#       <td id="T_3a22e_row1_col5" class="data row1 col5" >Specimen Type - Patient</td>
#       <td id="T_3a22e_row1_col6" class="data row1 col6" >0.982997</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a22e_row2_col0" class="data row2 col0" >Patient</td>
#       <td id="T_3a22e_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3a22e_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_3a22e_row2_col3" class="data row2 col3" >ENTITY</td>
#       <td id="T_3a22e_row2_col4" class="data row2 col4" >C1578481</td>
#       <td id="T_3a22e_row2_col5" class="data row2 col5" >Mail Claim Party - Patient</td>
#       <td id="T_3a22e_row2_col6" class="data row2 col6" >0.982997</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a22e_row3_col0" class="data row3 col0" >Patient</td>
#       <td id="T_3a22e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_3a22e_row3_col2" class="data row3 col2" >7</td>
#       <td id="T_3a22e_row3_col3" class="data row3 col3" >ENTITY</td>
#       <td id="T_3a22e_row3_col4" class="data row3 col4" >C1578483</td>
#       <td id="T_3a22e_row3_col5" class="data row3 col5" >Report source - Patient</td>
#       <td id="T_3a22e_row3_col6" class="data row3 col6" >0.982997</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a22e_row4_col0" class="data row4 col0" >Patient</td>
#       <td id="T_3a22e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_3a22e_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_3a22e_row4_col3" class="data row4 col3" >ENTITY</td>
#       <td id="T_3a22e_row4_col4" class="data row4 col4" >C1578484</td>
#       <td id="T_3a22e_row4_col5" class="data row4 col5" >Relationship modifier - Patient</td>
#       <td id="T_3a22e_row4_col6" class="data row4 col6" >0.982997</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a22e_row5_col0" class="data row5 col0" >chest pain</td>
#       <td id="T_3a22e_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_3a22e_row5_col2" class="data row5 col2" >32</td>
#       <td id="T_3a22e_row5_col3" class="data row5 col3" >ENTITY</td>
#       <td id="T_3a22e_row5_col4" class="data row5 col4" >C0008031</td>
#       <td id="T_3a22e_row5_col5" class="data row5 col5" >Chest Pain</td>
#       <td id="T_3a22e_row5_col6" class="data row5 col6" >0.984917</td>
#     </tr>
#     <tr>
#       <th id="T_3a22e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a22e_row
# <style type="text/css">
# #T_5e594 th {
#   text-align: left;
# }
# #T_5e594_row0_col0, #T_5e594_row0_col1, #T_5e594_row0_col2, #T_5e594_row0_col3, #T_5e594_row0_col4, #T_5e594_row0_col5, #T_5e594_row0_col6, #T_5e594_row0_col7, #T_5e594_row0_col8, #T_5e594_row0_col9, #T_5e594_row0_col10, #T_5e594_row1_col0, #T_5e594_row1_col1, #T_5e594_row1_col2, #T_5e594_row1_col3, #T_5e594_row1_col4, #T_5e594_row1_col5, #T_5e594_row1_col6, #T_5e594_row1_col7, #T_5e594_row1_col8, #T_5e594_row1_col9, #T_5e594_row1_col10, #T_5e594_row2_col0, #T_5e594_row2_col1, #T_5e594_row2_col2, #T_5e594_row2_col3, #T_5e594_row2_col4, #T_5e594_row2_col5, #T_5e594_row2_col6, #T_5e594_row2_col7, #T_5e594_row2_col8, #T_5e594_row2_col9, #T_5e594_row2_col10, #T_5e594_row3_col0, #T_5e594_row3_col1, #T_5e594_row3_col2, #T_5e594_row3_col3, #T_5e594_row3_col4, #T_5e594_row3_col5, #T_5e594_row3_col6, #T_5e594_row3_col7, #T_5e594_row3_col8, #T_5e594_row3_col9, #T_5e594_row3_col10, #T_5e594_row4_col0, #T_5e594_row4_col1, #T_5e594_row4_col2, #T_5e594_row4_col3, #T_5e594_row4_col4, #T_5e594_row4_col5, #T_5e594_row4_col6, #T_5e594_row4_col7, #T_5e594_row4_col8, #T_5e594_row4_col9, #T_5e594_row4_col10, #T_5e594_row5_col0, #T_5e594_row5_col1, #T_5e594_row5_col2, #T_5e594_row5_col3, #T_5e594_row5_col4, #T_5e594_row5_col5, #T_5e594_row5_col6, #T_5e594_row5_col7, #T_5e594_row5_col8, #T_5e594_row5_col9, #T_5e594_row5_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_5e594">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e594_level0_col0" class="col_heading level0 col0" >Text</th>
#       <th id="T_5e594_level0_col1" class="col_heading level0 col1" >Start</th>
#       <th id="T_5e594_level0_col2" class="col_heading level0 col2" >End</th>
#       <th id="T_5e594_level0_col3" class="col_heading level0 col3" >Label</th>
#       <th id="T_5e594_level0_col4" class="col_heading level0 col4" >UMLS_CUI</th>
#       <th id="T_5e594_level0_col5" class="col_heading level0 col5" >UMLS_Name</th>
#       <th id="T_5e594_level0_col6" class="col_heading level0 col6" >Score</th>
#       <th id="T_5e594_level0_col7" class="col_heading level0 col7" >ICD10_code</th>
#       <th id="T_5e594_level0_col8" class="col_heading level0 col8" >term_type</th>
#       <th id="T_5e594_level0_col9" class="col_heading level0 col9" >coding_system</th>
#       <th id="T_5e594_level0_col10" class="col_heading level0 col10" >ICD10_description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e594_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e594_row0_col0" class="data row0 col0" >Patient</td>
#       <td id="T_5e594_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5e594_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_5e594_row0_col3" class="data row0 col3" >ENTITY</td>
#       <td id="T_5e594_row0_col4" class="data row0 col4" >C0030705</td>
#       <td id="T_5e594_row0_col5" class="data row0 col5" >Patients</td>
#       <td id="T_5e594_row0_col6" class="data row0 col6" >0.982997</td>
#       <td id="T_5e594_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_5e594_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_5e594_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_5e594_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_5e594_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_5e594_row1_col0" class="data row1 col0" >chest pain</td>
#       <td id="T_5e594_row1_col1" class="data row1 col1" >22</td>
#       <td id="T_5e594_row1_col2" class="data row1 col2" >32</td>
#       <td id="T_5e594_row1_col3" class="data row1 col3" >ENTITY</td>
#       <td id="T_5e594_row1_col4" class="data row1 col4" >C0008031</td>
#       <td id="T_5e594_row1_col5" class="data row1 col5" >Chest Pain</td>
#       <td id="T_5e594_row1_col6" class="data row1 col6" >0.984917</td>
#       <td id="T_5e594_row1_col7" class="data row1 col7" >R07.9</td>
#       <td id="T_5e594_row1_col8" class="data row1 col8" >PT</td>
#       <td id="T_5e594_row1_col9" class="data row1 col9" >ICD10CM</td>
#       <td id="T_5e594_row1_col10" class="data row1 col10" >Chest pain, unspecified</td>
#     </tr>
#     <tr>
#       <th id="T_5e594_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_5e594_row2_col0" class="data row2 col0" >history</td>
#       <td id="T_5e594_row2_col1" class="data row2 col1" >54</td>
#       <td id="T_5e594_row2_col2" class="data row2 col2" >61</td>
#       <td id="T_5e594_row2_col3" class="data row2 col3" >ENTITY</td>
#       <td id="T_5e594_row2_col4" class="data row2 col4" >C0019664</td>
#       <td id="T_5e594_row2_col5" class="data row2 col5" >History</td>
#       <td id="T_5e594_row2_col6" class="data row2 col6" >0.994278</td>
#       <td id="T_5e594_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_5e594_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_5e594_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_5e594_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_5e594_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_5e594_row3_col0" class="data row3 col0" >hypertension</td>
#       <td id="T_5e594_row3_col1" class="data row3 col1" >65</td>
#       <td id="T_5e594_row3_col2" class="data row3 col2" >77</td>
#       <td id="T_5e594_row3_col3" class="data row3 col3" >ENTITY</td>
#       <td id="T_5e594_row3_col4" class="data row3 col4" >C0020538</td>
#       <td id="T_5e594_row3_col5" class="data row3 col5" >Hypertensive disease</td>
#       <td id="T_5e594_row3_col6" class="data row3 col6" >0.983864</td>
#       <td id="T_5e594_row3_col7" class="data row3 col7" >I10</td>
#       <td id="T_5e594_row3_col8" class="data row3 col8" >ET</td>
#       <td id="T_5e594_row3_col9" class="data row3 col9" >ICD10CM</td>
#       <td id="T_5e594_row3_col10" class="data row3 col10" >high blood pressure</td>
#     </tr>
#     <tr>
#       <th id="T_5e594_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_5e594_row4_col0" class="data row4 col0" >nausea</td>
#       <td id="T_5e594_row4_col1" class="data row4 col1" >37</td>
#       <td id="T_5e594_row4_col2" class="data row4 col2" >43</td>
#       <td id="T_5e594_row4_col3" class="data row4 col3" >ENTITY</td>
#       <td id="T_5e594_row4_col4" class="data row4 col4" >C0027497</td>
#       <td id="T_5e594_row4_col5" class="data row4 col5" >Nausea</td>
#       <td id="T_5e594_row4_col6" class="data row4 col6" >0.995102</td>
#       <td id="T_5e594_row4_col7" class="data row4 col7" >R11.0</td>
#       <td id="T_5e594_row4_col8" class="data row4 col8" >PT</td>
#       <td id="T_5e594_row4_col9" class="data row4 col9" >ICD10CM</td>
#       <td id="T_5e594_row4_col10" class="data row4 col10" >Nausea</td>
#     </tr>
#     <tr>
#       <th id="T_5e594_level0_row5" class="row_heading level0 row5" >23</th>
#       <td id="T_5e594_row5_col0" class="data row5 col0" >type 2 diabetes</td>
#       <td id="T_5e594_row5_col1" class="data row5 col1" >82</td>
#       <td id="T_5e594_row5_col2" class="data row5 col2" >97</td>
#       <td id="T_5e594_row5_col3" class="data row5 col3" >ENTITY</td>
#       <td id="T_5e594_row5_col4" class="data row5 col4" >C0011860</td>
#       <td id="T_5e594_row5_col5" class="data row5 col5" >Diabetes Mellitus, Non-Insulin-Dependent</td>
#       <td id="T_5e594_row5_col6" class="data row5 col6" >0.984797</td>
#       <td id="T_5e594_row5_col7" class="data row5 col7" >E11</td>
#       <td id="T_5e594_row5_col8" class="data row5 col8" >AB</td>
#       <td id="T_5e594_row5_col9" class="data row5 col9" >ICD10CM</td>
#       <td id="T_5e594_row5_col10" class="data row5 col10" >Type 2 diabetes mellitus</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## How to navigate umls mrconso file to get as much as possible 1:1 mappings

# %%
#step 1 download UMLS MRCONSO file (2GB) from their site and upload into postgre DB. 

#This is updated twice a year so minimal maintainance

#them look at distinct sab and tty combinations to establish priority

/*
PT	ICD10CM	- PREF TERM
AB	ICD10CM - ABBREVIATION
ET	ICD10CM - Entry term
HT	ICD10CM - Hierarchical term
PT	ICD10- PREF TERM
HT	ICD10 - Hierarchical term
PS	ICD10 - Short forms that needed full specification
PX	ICD10 - Short forms that needed full specification
HX	ICD10 - Expanded version of short hierarchical term
HS	ICD10 - Short or alternate version of hierarchical term
PT	SNOMEDCT - PREF TERM 
FN	SNOMEDCT - Full form of descriptor 
SY	SNOMEDCT - Synonym 
PTGB	SNOMEDCT - British preferred term 
SYGB	SNOMEDCT - British synonym 
MTH_PT	SNOMEDCT - Metathesaurus preferred term 
MTH_FN	SNOMEDCT - MTH Full form of descriptor 
MTH_SY	SNOMEDCT - MTH Designated synonym 
MTH_PTGB	SNOMEDCT - Metathesaurus-supplied form of British preferred term 
SB	SNOMEDCT - Named subset of a source 
MTH_SYGB	SNOMEDCT - Metathesaurus-supplied form of British synonym 
XM	SNOMEDCT - other 
*/
#I did this locally as this is 2 gb file.
WITH RankedConcepts AS (
    SELECT 
        cui, 
        code, 
        tty,
        sab,
        ROW_NUMBER() OVER (
            PARTITION BY cui 
            ORDER BY 
                CASE 
                    WHEN sab = 'ICD10CM' AND tty = 'PT' THEN 1  -- Highest priority
                    WHEN sab = 'ICD10CM' AND tty = 'AB' THEN 2  
                    WHEN sab = 'ICD10CM' AND tty = 'ET' THEN 3  
                    WHEN sab = 'ICD10CM' AND tty = 'HT' THEN 4  
                    WHEN sab = 'ICD10' AND tty = 'PT' THEN 5  
                    WHEN sab = 'ICD10' AND tty = 'HT' THEN 6  
                    WHEN sab = 'ICD10' AND tty IN ('PS', 'PX') THEN 7  
                    WHEN sab = 'ICD10' AND tty = 'HX' THEN 8  
                    WHEN sab = 'ICD10' AND tty = 'HS' THEN 9
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'PT' THEN 10
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'FN' THEN 11
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'SY' THEN 12
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'PTGB' THEN 13
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'SYGB' THEN 14
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'MTH_PT' THEN 15
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'MTH_FN' THEN 16
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'MTH_SY' THEN 17
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'MTH_PTGB' THEN 18
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'SB' THEN 19
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'MTH_SYGB' THEN 20
                    WHEN sab = 'SNOMEDCT_US' AND tty = 'XM' THEN 21
                    ELSE 25  -- Catch-all for any other TTY
                END
        ) AS rank
    FROM mrconso 
    WHERE sab IN ('ICD10CM', 'ICD10', 'SNOMEDCT_US')  -- Only consider ICD10CM and ICD10 sources
    and code !~ ('-') and suppress != 'O'
)
SELECT cui, code, str, tty, sab 
FROM RankedConcepts 
WHERE rank = 1;  -- Select only the highest-priority row per CUI

# %% [markdown]
# ## Getting primary diagnosis from MIMIC-IV Notes

# %%
import pandas as pd
import re
#loading clinical notes from mimic
csv_file_path = "/data0/mimic-iv-note/2.2/note/discharge.csv" 
df_discharge = pd.read_csv(csv_file_path)
print("notes loaded")
# Out:
# notes loaded

# %%
#PART 1 : GETTING THE PRIMARY DIAGNOSIS OUT OF THE NOTES
#Step 1: Define section keywords (you can adjust these based on your specific needs)
sections = {
    "discharge_diag": ["Discharge Diagnosis", "___ Diagnosis:"],
    "discharge_cond": ["Discharge Condition:"]
}


#Step 2: Initialize a list to store extracted DataFrames for each note
extracted_dfs = []

# Iterate over each clinical note in the DataFrame
for index, row in df_discharge.iterrows():
    clinical_notes = row['text']  # Get the clinical note text
    subject_id = row['subject_id']  # Get subject_id
    hadm_id = row['hadm_id']  # Get hadm_id
    
    # Clean up newlines and replace them with spaces
    clinical_notes = clinical_notes.replace("\n", "||")

    # Initialize a dictionary to store extracted data
    extracted_data = {key: "" for key in sections.keys()}
    
    # Iterate over each section to extract relevant data
    for section, phrases in sections.items():
        # Find the start position of the current section keyword
        for phrase in phrases:
            start_index = clinical_notes.lower().find(phrase.lower())
            if start_index != -1:
                # Determine where to stop extracting
                # Look for the next section keyword
                end_index = len(clinical_notes)  # Default to the end of the note
                for next_section in sections.keys():
                    if next_section != section:
                        for next_phrase in sections[next_section]:
                            next_start_index = clinical_notes.lower().find(next_phrase.lower(), start_index)
                            if next_start_index != -1 and next_start_index < end_index:
                                end_index = next_start_index
                # Extract the section text
                extracted_data[section] += clinical_notes[start_index:end_index].strip() + " "
                break  # Break after finding the first match for this section

    # Clean up extracted data to remove unwanted characters
    for key in extracted_data.keys():
        # Remove unwanted characters like "#" and "="
        extracted_data[key] = re.sub(r"[#=]", "", extracted_data[key])
        # Remove empty lines and trim whitespace
        cleaned_text = "\n".join([line.strip() for line in extracted_data[key].splitlines() if line.strip()])
        extracted_data[key] = cleaned_text
    
    # Add subject_id and hadm_id to the extracted data
    extracted_data['subject_id'] = subject_id
    extracted_data['hadm_id'] = hadm_id
    #extracted_data['future_admission_count'] = future_admission_count

    # Convert the extracted data for this note to a DataFrame and add to the list
    extracted_dfs.append(pd.DataFrame([extracted_data]))

print("extraction completed")    
# Step 3: Concatenate all extracted DataFrames
df_with_sections = pd.concat(extracted_dfs, ignore_index=True)

# Step 4: Drop specified columns from the final DataFrame
columns_to_drop = [ 'discharge_cond']
df_with_sections.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# Step 5: Define phrases to remove per column in a dictionary to clean th data as much as possible. you can awalys add to this if you find more.
phrases_to_remove_per_column = {
    "discharge_diag": ["Discharge Diagnosis:", "___", "PRIMARY DIAGNOSES", "Primary diagnosis:", "Primary:", 
                       "Primary Diagnosis", "Primary Diagnosis:", "PRIMARY:", "PRIMARY DIANGOSIS", "Primary Diagnoses:", "PRIMARY", "PRIMARY DIAGNOSIS",
                       "DIAGNOSIS", "DIAGNOSIS:", "SECONDARY DIAGNOSES", "Secondary:", "--------------------", "PREOPERATIVE DIAGNOSIS:", "POSTOPERATIVE DIAGNOSIS:", "Diagnosis",
                       "Secondary diagnosis:", "primary diagnosis:", "secondary diagnosis:", "Primary diagnosis", "Secondary diagnosis", "=", "-", ":", "SECONDARY :", "SECONDARY",
                       "*", "Secondary :", "Secondary Diagnoses", "Secondary Diagnoses:", "Diagnoses"]
    # Add other columns and their specific phrases here
}
print("cleaning completed")  
# Step 6: Iterate through each column and its phrases
for col, phrases in phrases_to_remove_per_column.items():
    if col in df_with_sections.columns:
        for phrase in phrases:
            # Replace each phrase with an empty string and strip whitespace
            df_with_sections[col] = df_with_sections[col].str.replace(phrase, "", regex=False).str.strip()

# Improve display settings for Jupyter
#pd.set_option("display.max_columns", None)  # Show all columns
#pd.set_option("display.max_rows", 50)  # Adjust number of rows displayed
#pd.set_option("display.width", 1000)  # Prevent line wrapping

# Display the after extraction
#display(df_with_sections.style.set_properties(**{"text-align": "left"}).set_table_styles(
    #[{"selector": "th", "props": [("text-align", "left")]}]
#))

df_with_sections.head(20)
# Out:
# extraction completed
# cleaning completed
#                                        discharge_diag  subject_id   hadm_id
# 0                    ||Ascites from Portal HTN|||| ||    10000032  22595853
# 1   ||  diuretic refractory ascites|| HCV cirrhosi...    10000032  22841357
# 2   ||||Hypotension||Hyperkalemia||Acute Kidney In...    10000032  29079034
# 3   || ||||Decompensated HCV cirrhosis||Hyperkalem...    10000032  25742920
# 4                                    || Dementia|| ||    10000084  23052089
# 5   || ||dysphagia and foreign body sensation|||| ...    10000117  22927623
# 6   ||Left valgus impacted femoral neck fracture||...    10000117  27988844
# 7   |||| Acute muscular hematoma, right flank|| He...    10000248  20600184
# 8                       ||renal cell carcinoma|||| ||    10000560  28979390
# 9          ||Nasal fracture||Epistaxis||NSTEMI|||| ||    10000764  27897940
# 10       |||| alcoholrelated hepatitis|| ascites|| ||    10000826  20032235
# 11                       || Alcoholic hepatitis.|| ||    10000826  21086876
# 12  ||||Ascites||Portal hypertension||Alcoholic he...    10000826  28289260
# 13  ||Axis I||Major depressive disorder, severe, w...    10000883  25221576
# 14        ||High grade small bowel obstruction|||| ||    10000935  29541074
# 15     ||Liver and Lung Mets of unkown primary|||| ||    10000935  21738619
# 16  ||Metastatic disease of unknown primary Weakne...    10000935  26381316
# 17         ||||Metastatic colon adenocarcinoma|||| ||    10000935  25849114
# 18  ||Hypertension with hypertensive urgency||Myoc...    10000980  29654838
# 19  || ||Severe mitral regurgitation||Coronary art...    10000980  26913865

# %%
##PART 2: GET COUNTS OF THIS RAW EXTRACTION
print(len(df_with_sections))

print( df_with_sections['subject_id'].nunique() )
# Out:
# 331794
# 145915

# %%
##PART 3: TRANSFORM INTO A CLEAN MAPPABLE FORMAT AND DROP DUPLICATES

# Create a copy of the EXTRACTED DataFrame
df_transformed = df_with_sections.copy()

# Split 'discharge_diag' on '|' and explode into separate rows
df_transformed['discharge_diag'] = df_transformed['discharge_diag'].str.split('|')
df_transformed = df_transformed.explode('discharge_diag')

# Remove any empty strings or spaces that might result from splitting
df_transformed['discharge_diag'] = df_transformed['discharge_diag'].str.strip()

# Drop rows where 'discharge_diag' is empty or contains only punctuation
df_transformed = df_transformed[df_transformed['discharge_diag'].str.contains(r'[a-zA-Z0-9]', regex=True)]

# Convert discharge_diag to lowercase for case-insensitive comparison
df_transformed["discharge_diag_lower"] = df_transformed["discharge_diag"].str.lower()

# Drop duplicate diagnoses within the same subject_id
df_transformed = df_transformed.drop_duplicates(subset=["subject_id", "discharge_diag_lower"], keep="first")

# Drop the temporary lowercase column
df_transformed = df_transformed.drop(columns=["discharge_diag_lower"])


df_transformed = df_transformed.reset_index(drop=True)

# Improve display settings for Jupyter
#pd.set_option("display.max_columns", None)  # Show all columns
#pd.set_option("display.max_rows", 50)  # Adjust number of rows displayed
#pd.set_option("display.width", 1000)  # Prevent line wrapping

# Display df_transformed with improved formatting
#display(df_transformed.style.set_properties(**{"text-align": "left"}).set_table_styles(
    #[{"selector": "th", "props": [("text-align", "left")]}]
#))

df_transformed.head(20)

#save to csv
#df_transformed.to_csv("structured_diagnosis")
# Out:
#                                 discharge_diag  subject_id   hadm_id
# 0                      Ascites from Portal HTN    10000032  22595853
# 1                  diuretic refractory ascites    10000032  22841357
# 2       HCV cirrhosis, HIV, hyponatremia, COPD    10000032  22841357
# 3                                  Hypotension    10000032  29079034
# 4                                 Hyperkalemia    10000032  29079034
# 5                          Acute Kidney Injury    10000032  29079034
# 6                                          HIV    10000032  29079034
# 7                                    Cirrhosis    10000032  29079034
# 8                                         COPD    10000032  29079034
# 9                  Decompensated HCV cirrhosis    10000032  25742920
# 10                                Hyponatremia    10000032  25742920
# 11                                    Dementia    10000084  23052089
# 12        dysphagia and foreign body sensation    10000117  22927623
# 13                                        GERD    10000117  22927623
# 14  Left valgus impacted femoral neck fracture    10000117  27988844
# 15        Acute muscular hematoma, right flank    10000248  20600184
# 16          Hemophilia, factor VIII deficiency    10000248  20600184
# 17                        renal cell carcinoma    10000560  28979390
# 18                              Nasal fracture    10000764  27897940
# 19                                   Epistaxis    10000764  27897940

# %%
##PART 4 GET COUNTS AFTER TRANSFORMATION
print(len(df_transformed))

print( df_transformed['subject_id'].nunique() )
# Out:
# 1086388
# 145352

# %% [markdown]
# ##USING THE TRANSFORMED DIAGNOSIS FROM NOTES TO MAP WITH SPACY MODEL- Contnued in part 2 file
